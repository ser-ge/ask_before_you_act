# %%
import gym
import gym_minigrid
from gym import wrappers
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

from oracle import Oracle, OracleWrapper
from lang import parser, TreeToGrid

def show_state(env, step=0):
  
    plt.figure(3, figsize=(20, 20))
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    # pause for plots to update
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.0001)

# %%
oracle = Oracle(parser, TreeToGrid)
env = gym.make("MiniGrid-MultiRoom-N4-S5-v0")

env = OracleWrapper(env, oracle)

# %%
obvs = env.reset()

for _ in range(10):
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    show_state(env)
    if done: break

# %%
env._answer("blue door is closed")
# Out:
# True

# %%
env._answer("red door is open")
# Out:
# False

# %%
env._answer("blue door isnt closed")
# Out:
# invalid syntax

# %%
env._answer("purple door is closed")
# Out:
# no such object
